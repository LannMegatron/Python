# %% [markdown]
# # 1) Transfer Functions

# %%
# First Order System With Integrator

import numpy as np       # Calling library numpy
import control           # Calling library control

num = np.array ([2])     # Numerator
den = np.array ([3, 1])  # Denumeratot

H = control.tf(num,den)  # Fungsi Transfer

print('H(s) =',H )       # Memunculkan Fungsi Transfer
# Out:
# H(s) = <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    2
# -------
# 3 s + 1

# %%
import numpy as np
import control
num = np.array ([3])
den = np.array ([2 , 1, 0])
H = control.tf(num , den)
print ('H(s) =', H)
# Out:
# H(s) = <TransferFunction>: sys[1]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     3
# ---------
# 2 s^2 + s

# %%
import numpy as np
import control
num = np.array ([4])
den = np.array ([3 , -2, 1])
H = control.tf(num , den)
print ('H(s) =', H)
# Out:
# H(s) = <TransferFunction>: sys[2]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#        4
# ---------------
# 3 s^2 - 2 s + 1

# %%
import numpy as np
import control
num = np.array ([4, 1])
den = np.array ([2 , 5, -2])
H = control.tf(num , den)
print ('H(s) =', H)
# Out:
# H(s) = <TransferFunction>: sys[3]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     4 s + 1
# ---------------
# 2 s^2 + 5 s - 2

# %% [markdown]
# # SciPy Signal

# %%
import numpy as np

import scipy.signal as signal
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([2])
den = np.array([3 , 1])
H = signal.TransferFunction(num , den)
print ('H(s) =', H)

# Step Response
t, y = signal.step(H)

# Plotting
plt.plot(t, y)
plt.title("Step Response")
plt.xlabel("t")
plt.ylabel("y")
plt.grid()
plt.show()
# Out:
# H(s) = TransferFunctionContinuous(
# array([0.66666667]),
# array([1.        , 0.33333333]),
# dt: None
# )

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

num = np.array([2])
den = np.array([3 , 1])

H = control.tf(num , den)
print ('H(s) =', H)

t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()
# Out:
# H(s) = <TransferFunction>: sys[4]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    2
# -------
# 3 s + 1

# %%
import control
import matplotlib.pyplot as plt

s = control.TransferFunction.s

H = (2)/(3*s + 1)

print ('H(s) =', H)

t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()
# Out:
# H(s) = <TransferFunction>: sys[12]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    2
# -------
# 3 s + 1

# %%
import control
import matplotlib.pyplot as plt

s = control.TransferFunction.s

H = (6*s + 1)/(s**2 + 4*s + 8)

print ('H(s) =', H)

t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()
# Out:
# H(s) = <TransferFunction>: sys[27]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    6 s + 1
# -------------
# s^2 + 4 s + 8

# %%
import numpy as np

import matplotlib.pyplot as plt
import control
K = 3
T = 4

num = np.array ([K])
den = np.array ([T , 1])
H = control.tf(num , den)
print ('H(s) =', H)
t, y = control.step_response(H)
plt.plot(t,y)
plt.title("Step Response")
plt.grid()
# Out:
# H(s) = <TransferFunction>: sys[30]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    3
# -------
# 4 s + 1

# %% [markdown]
# # First Order Transfer Functions

# %%
import numpy as np
import control
import matplotlib.pyplot as plt

K = 10
Tarray = [5, 10, 30, 50]

start = 0
stop = 200
step = 0.1
t = np.arange(start, stop, step)

for T in Tarray:    
    #Create Transfer Function
    num = np.array ([K])
    den = np.array ([T , 1])
    H = control.tf(num , den)
    print ('H(s) =', H)

    # Step Response
    t, y = control.step_response(H, t)
    # Plot
    plt.plot(t, y)

plt.title("Step Response for different T")
plt.xlabel("t")
plt.ylabel("y")
plt.legend(Tarray)
plt.grid()
plt.show()
# Out:
# H(s) = <TransferFunction>: sys[57]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#   10
# -------
# 5 s + 1
#
# H(s) = <TransferFunction>: sys[59]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    10
# --------
# 10 s + 1
#
# H(s) = <TransferFunction>: sys[61]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    10
# --------
# 30 s + 1
#
# H(s) = <TransferFunction>: sys[63]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    10
# --------
# 50 s + 1

# %%
import numpy as np
import control
import matplotlib.pyplot as plt

T = 10
Karray = [1, 3, 5, 10]

start = 0
stop = 60
step = 0.1
t = np.arange(start, stop, step)

for K in Karray:
    #Create Transfer Function
    num = np.array ([K])
    den = np.array ([T , 1])
    
    H = control.tf(num , den)
    
    print ('H(s) =', H)
    # Step Response
    t, y = control.step_response(H, t)
    # Plot
    plt.plot(t, y)

plt.title("Step Response for different K")
plt.xlabel("t")
plt.ylabel("y")
plt.legend(Karray)
plt.grid()
plt.show()
# Out:
# H(s) = <TransferFunction>: sys[73]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    1
# --------
# 10 s + 1
#
# H(s) = <TransferFunction>: sys[75]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    3
# --------
# 10 s + 1
#
# H(s) = <TransferFunction>: sys[77]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    5
# --------
# 10 s + 1
#
# H(s) = <TransferFunction>: sys[79]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    10
# --------
# 10 s + 1

# %% [markdown]
# # Integrator

# %%
import numpy as np

import matplotlib.pyplot as plt
import control

K = 3

num = np.array ([K])
den = np.array ([1, 0])

H = control.tf(num , den)
print ('H(s) =', H)

t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()
# Out:
# H(s) = <TransferFunction>: sys[81]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# 3
# -
# s

# %%
import numpy as np
import matplotlib.pyplot as plt
import control

# Time Delay
Tau = 2

# Approximation Order
N = 5

[num_pade,den_pade] = control.pade(Tau,N)
Hpade = control.tf(num_pade,den_pade)
print ('Hpade(s) =', Hpade)

start = 0
stop = 10
step = 0.1

t = np.arange(start, stop, step)

t, y = control.step_response(Hpade, t)

plt.plot(t,y)
title = "Pade Aprroximation, N=" + str(N)
plt.title(title)
plt.grid()
# Out:
# Hpade(s) = <TransferFunction>: sys[84]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# -s^5 + 15 s^4 - 105 s^3 + 420 s^2 - 945 s + 945
# -----------------------------------------------
# s^5 + 15 s^4 + 105 s^3 + 420 s^2 + 945 s + 945

# %%
import numpy as np
import matplotlib.pyplot as plt
import control

# Time Delay
Tau = 2

N = 5

start = 0
stop = 10
step = 0.1
t = np.arange(start, stop, step)

N = [1, 2, 3, 5, 10]

for n in N:
    [num_pade,den_pade] = control.pade(Tau,n)
    Hpade = control.tf(num_pade,den_pade)
    print ('Hpade(s) =', Hpade)
    
    t, y = control.step_response(Hpade, t)
    
    plt.plot(t,y)
    
plt.title("Pade Aprroximations")
plt.legend(N)
plt.grid()
# Out:
# Hpade(s) = <TransferFunction>: sys[86]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# -s + 1
# ------
# s + 1
#
# Hpade(s) = <TransferFunction>: sys[88]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 - 3 s + 3
# -------------
# s^2 + 3 s + 3
#
# Hpade(s) = <TransferFunction>: sys[90]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# -s^3 + 6 s^2 - 15 s + 15
# ------------------------
# s^3 + 6 s^2 + 15 s + 15
#
# Hpade(s) = <TransferFunction>: sys[92]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# -s^5 + 15 s^4 - 105 s^3 + 420 s^2 - 945 s + 945
# -----------------------------------------------
# s^5 + 15 s^4 + 105 s^3 + 420 s^2 + 945 s + 945
#
# Hpade(s) = <TransferFunction>: sys[94]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^10 - 55 s^9 + 1485 s^8 - 2.574e+04 s^7 + 3.153e+05 s^6 - 2.838e+06 s^5 + 1.892e+07 s^4 - 9.189e+07 s^3 + 3.101e+08 s^2 - 6.547e+08 s + 6.547e+08
# --------------------------------------------------------------------------------------------------------------------------------------------------
# s^10 + 55 s^9 + 1485 s^8 + 2.574e+04 s^7 + 3.153e+05 s^6 + 2.838e+06 s^5 + 1.892e+07 s^4 + 9.189e+07 s^3 + 3.101e+08 s^2 + 6.547e+08 s + 6.547e+08

# %% [markdown]
# # First Order With Time Delay

# %%
import numpy as np
import matplotlib.pyplot as plt
import control

K = 3
T = 4

num = np.array ([K])
den = np.array ([T , 1])

H1 = control.tf(num , den)
print ('H1(s) =', H1)

Tau = 2
N = 5 # Order of the Approximation
[num_pade,den_pade] = control.pade(Tau,N)
Hpade = control.tf(num_pade,den_pade)
print ('Hpade(s) =', Hpade)

H = control.series(H1, Hpade)
print ('H(s) =', H)

t, y = control.step_response(H)

plt.plot(t,y)
plt.title("H(s)")
plt.grid()
# Out:
# H1(s) = <TransferFunction>: sys[96]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    3
# -------
# 4 s + 1
#
# Hpade(s) = <TransferFunction>: sys[97]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# -s^5 + 15 s^4 - 105 s^3 + 420 s^2 - 945 s + 945
# -----------------------------------------------
# s^5 + 15 s^4 + 105 s^3 + 420 s^2 + 945 s + 945
#
# H(s) = <TransferFunction>: sys[98]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     -3 s^5 + 45 s^4 - 315 s^3 + 1260 s^2 - 2835 s + 2835
# -------------------------------------------------------------
# 4 s^6 + 61 s^5 + 435 s^4 + 1785 s^3 + 4200 s^2 + 4725 s + 945

# %% [markdown]
# # Second Order Transfer Functions

# %%
import numpy as np

import scipy.signal as signal
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([4])
den = np.array([3 , 2, 1])

H = signal.TransferFunction(num , den)

print ('H(s) =', H)

# Step Response
t, y = signal.step(H)

# Plotting
plt.plot(t, y)
plt.title("Step Response")
plt.xlabel("t")
plt.ylabel("y")
plt.grid()
plt.show()
# Out:
# H(s) = TransferFunctionContinuous(
# array([1.33333333]),
# array([1.        , 0.66666667, 0.33333333]),
# dt: None
# )

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([4])
den = np.array([3 , 2, 1])

H = control.tf(num , den)
print ('H(s) =', H)

# Step Response
t, y = control.step_response(H)

# Plotting
plt.plot(t, y)
plt.title("Step Response")
plt.xlabel("t")
plt.ylabel("y")
plt.grid()
plt.show()
# Out:
# H(s) = <TransferFunction>: sys[101]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#        4
# ---------------
# 3 s^2 + 2 s + 1

# %% [markdown]
# # Poles and Zeros

# %%
import numpy as np
import control

num = np.array([1, 1])
den = np.array([3, 1])
H1 = control.tf(num , den)

num = np.array([2, 1])
den = np.array([4, 1])
H2 = control.tf(num , den)

H = control.series(H1,H2)
print ('H(s) =', H)

z = control.zeros(H)
print ('z =', z)

p = control.poles(H)
print ('p =', p)

control.pzmap(H)
# Out:
# H(s) = <TransferFunction>: sys[128]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# 2 s^2 + 3 s + 1
# ----------------
# 12 s^2 + 7 s + 1
#
# z = [-1. +0.j -0.5+0.j]
# p = [-0.33333333+0.j -0.25      +0.j]

# %% [markdown]
# # Poles and Stability

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([2])
den = np.array([3 , 1])

H = control.tf(num , den)
print ('H(s) =', H)

# Poles
p = control.poles(H)
print ('p =', p)

# Step Response
t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()

control.pzmap(H)
# Out:
# H(s) = <TransferFunction>: sys[129]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    2
# -------
# 3 s + 1
#
# p = [-0.33333333+0.j]

# %% [markdown]
# # Marginally Stable System

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([3])
den = np.array([1, 0, 1])

H = control.tf(num , den)
print ('H(s) =', H)

# Poles
p = control.poles(H)
print ('p =', p)

# Step Response
tstart = 0; tstop = 20; tstep = 0.1
t = np.arange(tstart, tstop, tstep)
t, y = control.step_response(H, t)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()

control.pzmap(H)
# Out:
# H(s) = <TransferFunction>: sys[152]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    3
# -------
# s^2 + 1
#
# p = [-0.+1.j  0.-1.j]

# %% [markdown]
# # Unstable System

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([2])
den = np.array([3 , -1])

H = control.tf(num , den)
print ('H(s) =', H)

# Poles
p = control.poles(H)
print ('p =', p)

# Step Response
t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()

control.pzmap(H)
# Out:
# H(s) = <TransferFunction>: sys[149]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    2
# -------
# 3 s - 1
#
# p = [0.33333333+0.j]

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([2, 1])
den = np.array([3 , -1, -2])

H = control.tf(num , den)
print ('H(s) =', H)

# Poles
p = control.poles(H)
print ('p =', p)

# Step Response
t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()

control.pzmap(H)
# Out:
# H(s) = <TransferFunction>: sys[146]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#    2 s + 1
# -------------
# 3 s^2 - s - 2
#
# p = [ 1.        +0.j -0.66666667+0.j]

# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# Define Transfer Function
num = np.array([2])
den = np.array([1, 0, 0])

H = control.tf(num , den)
print ('H(s) =', H)

# Poles
p = control.poles(H)
print ('p =', p)

# Step Response
t, y = control.step_response(H)

plt.plot(t,y)
plt.title("Step Response")
plt.grid()

control.pzmap(H)
# Out:
# H(s) = <TransferFunction>: sys[143]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#  2
# ---
# s^2
#
# p = [0.+0.j 0.+0.j]
